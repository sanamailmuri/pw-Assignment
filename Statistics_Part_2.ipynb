# %% [markdown]
# **1. What is hypothesis testing in statistics**
#
# Hypothesis testing is a statistical method used to make decisions or inferences about population parameters based on sample data. It involves formulating a null hypothesis and an alternative hypothesis and using sample data to determine which hypothesis is more likely to be true.
#
# **2.What is the null hypothesis, and how does it differ from the alternative hypothesis**
#
# The null hypothesis (H₀) is a statement that there is no effect or no difference, and it is assumed to be true until evidence suggests otherwise. The alternative hypothesis (H₁ or Ha) is a statement that there is an effect or a difference. Hypothesis testing evaluates whether the observed data provides sufficient evidence to reject the null hypothesis in favor of the alternative.
#
# 3**What is the significance level in hypothesis testing, and why is it important**
#
# The significance level (α) is the probability of rejecting the null hypothesis when it is actually true. It is a threshold set by the researcher (commonly 0.05 or 5%) that determines how much evidence is required to reject the null hypothesis. It controls the rate of Type 1 errors.
#
# **4.What does a P-value represent in hypothesis testing**
#
# A P-value is the probability of obtaining a test statistic at least as extreme as the one observed, assuming the null hypothesis is true. It quantifies the strength of evidence against the null hypothesis.
#
# 5.How do you interpret the P-value in hypothesis testing
#
# If the P-value is less than or equal to the significance level (α), the null hypothesis is rejected in favor of the alternative hypothesis. If the P-value is greater than α, there is not enough evidence to reject the null hypothesis.
#
# **6.What are Type 1 and Type 2 errors in hypothesis testing**
#
# A Type 1 error occurs when the null hypothesis is rejected when it is actually true (false positive). A Type 2 error occurs when the null hypothesis is not rejected when the alternative hypothesis is true (false negative).
#
# **7.What is the difference between a one-tailed and a two-tailed test in hypothesis testi**ng
#
# A one-tailed test examines if a parameter is either greater than or less than a certain value. A two-tailed test checks if a parameter is significantly different from a certain value in either direction (greater or less).
#
# **8.What is the Z-test, and when is it used in hypothesis testing**
#
# A Z-test is used to determine whether there is a significant difference between sample and population means when the population standard deviation is known and the sample size is large (n ≥ 30).
#
# **9.How do you calculate the Z-score, and what does it represent in hypothesis testing**
#
# The Z-score is calculated as:
# Z = (X̄ - μ) / (σ / √n)
# where X̄ is the sample mean, μ is the population mean, σ is the population standard deviation, and n is the sample size. It represents how many standard deviations the sample mean is from the population mean.
#
# **10.What is the T-distribution, and when should it be used instead of the normal distribution**
#
# The T-distribution is a probability distribution used when the sample size is small (n < 30) and/or the population standard deviation is unknown. It has heavier tails than the normal distribution to account for variability.
#
# **11.What is the difference between a Z-test and a T-test**
#
# A Z-test is used when the population standard deviation is known and the sample size is large. A T-test is used when the population standard deviation is unknown and/or the sample size is small.
#
# **12.What is the T-test, and how is it used in hypothesis testing**
#
# A T-test compares the means of one or two groups to determine if there is a statistically significant difference between them. It is used when the population standard deviation is unknown.
#
# **13.What is the relationship between Z-test and T-test in hypothesis testing**
#
# Both tests are used to assess hypotheses about population means. The choice depends on whether the population standard deviation is known (Z-test) or unknown (T-test) and the sample size.
#
# **14.What is a confidence interval, and how is it used to interpret statistical results**
#
# A confidence interval is a range of values, derived from sample data, that is likely to contain the population parameter. It provides an estimate of the parameter with a specified level of confidence, typically 95%.
#
# **15.What is the margin of error, and how does it affect the confidence interval**
#
# The margin of error is the maximum expected difference between the sample estimate and the true population value. A larger margin of error results in a wider confidence interval, indicating less precision.
#
# **16.How is Bayes' Theorem used in statistics, and what is its significance**
#
# Bayes' Theorem is used to update the probability of a hypothesis based on new evidence. It is significant for incorporating prior knowledge and evidence in statistical inference and decision-making.
#
# **17.What is the Chi-square distribution, and when is it used**
#
# The Chi-square distribution is a probability distribution used in tests of independence and goodness of fit for categorical data. It is used when comparing observed frequencies to expected frequencies.
#
# **18.What is the Chi-square goodness of fit test, and how is it applied**
#
# The Chi-square goodness of fit test evaluates whether the observed frequency distribution of a categorical variable matches an expected distribution. It compares the observed and expected counts using the Chi-square statistic.
#
# 19.**What is the F-distribution, and when is it used in hypothesis testing**
#
# The F-distribution is a probability distribution used primarily in analysis of variance (ANOVA) and in comparing two variances. It is used when testing hypotheses involving multiple group variances.
#
# 20.**What is an ANOVA test, and what are its assumptions**
#
# ANOVA (Analysis of Variance) tests whether there are statistically significant differences between the means of three or more independent groups. Its assumptions are independence, normality, and homogeneity of variances.
#
# 21.**What are the different types of ANOVA tests**
#
# The different types are One-way ANOVA (one independent variable), Two-way ANOVA (two independent variables), and Repeated Measures ANOVA (same subjects tested multiple times).
#
# **22.What is the F-test, and how does it relate to hypothesis testing**
#
# The F-test compares the variances of two or more groups to determine if they are significantly different. It is used in ANOVA and regression analysis as a part of hypothesis testing.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Z-test for comparing a sample mean to a known population mean
def z_test(sample, pop_mean, pop_std):
    n = len(sample)
    sample_mean = np.mean(sample)
    z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p = 2 * (1 - stats.norm.cdf(abs(z)))
    return z, p

# Simulate random data and perform hypothesis test
sample_data = np.random.normal(loc=52, scale=10, size=50)
pop_mean = 50
pop_std = 10
z, p = z_test(sample_data, pop_mean, pop_std)

# One-sample Z-test
z_one_sample, p_one_sample = z_test(sample_data, 50, 10)

# Two-tailed Z-test and visualization
x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x)
z_val = (np.mean(sample_data) - 50) / (10 / np.sqrt(len(sample_data)))
plt.plot(x, y)
plt.fill_between(x, y, where=(x <= -abs(z_val)) | (x >= abs(z_val)), color='red', alpha=0.3)
plt.axvline(z_val, color='blue')
plt.title("Two-tailed Z-test Decision Region")
plt.show()

# Type I and Type II Error visualization
def type1_type2(alpha, beta):
    x = np.linspace(-5, 5, 1000)
    h0 = stats.norm.pdf(x, 0, 1)
    h1 = stats.norm.pdf(x, 2, 1)
    plt.plot(x, h0, label="H0")
    plt.plot(x, h1, label="H1")
    crit_val = stats.norm.ppf(1 - alpha)
    plt.fill_between(x, h0, where=(x > crit_val), color='red', alpha=0.5, label="Type I")
    plt.fill_between(x, h1, where=(x < crit_val), color='blue', alpha=0.5, label="Type II")
    plt.legend()
    plt.title("Type I and Type II Errors")
    plt.show()

type1_type2(0.05, 0.2)

# Independent T-test
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)
t_ind, p_ind = stats.ttest_ind(group1, group2)

# Paired sample T-test
before = np.random.normal(60, 5, 30)
after = before + np.random.normal(-2, 2, 30)
t_paired, p_paired = stats.ttest_rel(before, after)
plt.plot(before, label="Before")
plt.plot(after, label="After")
plt.legend()
plt.title("Paired Sample Comparison")
plt.show()

# Simulate data and compare Z-test and T-test
sample = np.random.normal(100, 15, 25)
z_val, z_p = z_test(sample, 100, 15)
t_val, t_p = stats.ttest_1samp(sample, 100)

# Confidence interval
def confidence_interval(sample, confidence=0.95):
    mean = np.mean(sample)
    sem = stats.sem(sample)
    margin = sem * stats.t.ppf((1 + confidence) / 2, len(sample) - 1)
    return mean - margin, mean + margin

conf_interval = confidence_interval(sample)

# Margin of error
def margin_of_error(sample, confidence=0.95):
    sem = stats.sem(sample)
    return sem * stats.t.ppf((1 + confidence) / 2, len(sample) - 1)

moe = margin_of_error(sample)

# Bayesian inference using Bayes' Theorem
def bayes(prior_A, prob_B_given_A, prob_B):
    return (prob_B_given_A * prior_A) / prob_B

posterior = bayes(0.01, 0.9, 0.05)

# Chi-square test for independence
data = pd.DataFrame({'A': np.random.choice(['Yes', 'No'], 100), 'B': np.random.choice(['High', 'Low'], 100)})
contingency = pd.crosstab(data['A'], data['B'])
chi2, p_val, dof, expected = stats.chi2_contingency(contingency)

# Expected frequencies
expected_freq = expected

# Goodness-of-fit test
observed = [50, 30, 20]
total_observed = sum(observed)
# If the expected frequencies are based on a proportion, scale them to the total observed.
# For this example, assuming equal expected frequencies
expected = [total_observed / len(observed)] * len(observed)

chi2_gof, p_gof = stats.chisquare(f_obs=observed, f_exp=expected)

# Chi-square distribution visualization
df = 4
x = np.linspace(0, 20, 1000)
y = stats.chi2.pdf(x, df)
plt.plot(x, y)
plt.title("Chi-square Distribution")
plt.show()

# F-test for comparing variances
sample1 = np.random.normal(10, 2, 100)
sample2 = np.random.normal(10, 3, 100)
f_stat = np.var(sample1, ddof=1) / np.var(sample2, ddof=1)
p_val_f = 1 - stats.f.cdf(f_stat, dfn=len(sample1)-1, dfd=len(sample2)-1)

# ANOVA test
group_a = np.random.normal(55, 10, 30)
group_b = np.random.normal(60, 10, 30)
group_c = np.random.normal(65, 10, 30)
f_anova, p_anova = stats.f_oneway(group_a, group_b, group_c)

# One-way ANOVA and plot
plt.boxplot([group_a, group_b, group_c], labels=['A', 'B', 'C'])
plt.title("One-way ANOVA")
plt.show()

# ANOVA assumptions
def check_anova_assumptions(*groups):
    for group in groups:
        stat, p = stats.shapiro(group)
        print(f"Normality p={p}")
    stat, p = stats.levene(*groups)
    print(f"Equal variance p={p}")

check_anova_assumptions(group_a, group_b, group_c)

# Two-way ANOVA
df = pd.DataFrame({
    'A': np.tile(['X', 'Y'], 30),
    'B': np.repeat(['M', 'N', 'O'], 20),
    'Score': np.random.normal(50, 10, 60)
})
from statsmodels.formula.api import ols
import statsmodels.api as sm
model = ols('Score ~ A * B', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
sm.graphics.plot_partregress_grid(model)
plt.show()

# F-distribution visualization
x = np.linspace(0.01, 5, 1000)
y = stats.f.pdf(x, dfn=5, dfd=20)
plt.plot(x, y)
plt.title("F-distribution")
plt.show()

# Simulate data and hypothesis testing on mean
data_sim = np.random.normal(70, 10, 100)
t_sim, p_sim = stats.ttest_1samp(data_sim, 75)

# Chi-square test for population variance
n = 30
sample_var = np.var(sample_data, ddof=1)
pop_var = 100
chi2_stat = (n - 1) * sample_var / pop_var
p_chi2 = 1 - stats.chi2.cdf(chi2_stat, df=n-1)

# Z-test for comparing proportions
def z_test_proportions(p1, n1, p2, n2):
    p_pool = (p1*n1 + p2*n2) / (n1 + n2)
    se = np.sqrt(p_pool * (1 - p_pool) * (1/n1 + 1/n2))
    z = (p1 - p2) / se
    p = 2 * (1 - stats.norm.cdf(abs(z)))
    return z, p

z_prop, p_prop = z_test_proportions(0.6, 100, 0.5, 100)

# F-test for comparing variances
f_stat2 = np.var(group1, ddof=1) / np.var(group2, ddof=1)
p_f2 = 1 - stats.f.cdf(f_stat2, dfn=len(group1)-1, dfd=len(group2)-1)
x = np.linspace(0.5, 2, 1000)
plt.plot(x, stats.f.pdf(x, len(group1)-1, len(group2)-1))
plt.title("F-test Visualization")
plt.show()

# Chi-square goodness of fit with simulated data
sim_obs = np.random.randint(10, 50, 5)
sim_exp = [sum(sim_obs) / len(sim_obs)] * len(sim_obs)
chi2_sim, p_sim = stats.chisquare(sim_obs, f_exp=sim_exp)
# Out:
# <ipython-input-2-11ad9abcb465>:130: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group_a, group_b, group_c], labels=['A', 'B', 'C'])
# Normality p=0.8846151571028515
# Normality p=0.8763473148274641
# Normality p=0.19876699926822772
# Equal variance p=0.04129898221902191
